# %%
import sys
sys.path.insert(0, "python/")

from unityagents import UnityEnvironment
import numpy as np
import torch
from dqn.dqn_agent_v2 import Agent
from collections import deque

from model import ActorModel, CriticModel
from agent import Agent as PpoAgent

# %%
env = UnityEnvironment(file_name="Soccer_Env/Soccer.exe")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 2
#         Number of External Brains : 2
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: GoalieBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 112
#         Number of stacked Vector Observation: 3
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Unity brain name: StrikerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 112
#         Number of stacked Vector Observation: 3
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 6
#         Vector Action descriptions: , , , , ,

# %%
def ball_reward(state):
    reward = 0.0
    if not any(state[0::8]):
        reward = -0.03
    # Reward for kicking the ball
    else:
        idx = np.where(state[0::8])[0]
        distance = state[idx*8 + 7]
        if (np.amin(distance) <= 0.03):
            reward = 0.3

    return reward

# %%
def dqn(n_episodes=2000, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    scores = []
    scores_window = deque(maxlen=100)
    eps = eps_start
    g_losses = []
    g_losses_window = deque(maxlen=100)
    s_losses = []
    s_losses_window = deque(maxlen=100)
    for i_episode in range(1, n_episodes+1):
        env_info  = env.reset(train_mode=True)
        score = 0
        ball_reward_val = 0.0
        
        g_states = env_info[g_brain_name].vector_observations
        s_states = env_info[s_brain_name].vector_observations

        g_scores = np.zeros(num_g_agents)
        s_scores = np.zeros(num_s_agents)
        
        for t in range(max_t):
            action_g_0 = g_agent.act(g_states[0], eps)
            action_s_0 = s_agent.act(s_states[0], eps)  
            
            # Set other team to random
            action_g_1 = np.asarray( [np.random.choice(g_action_size)] ) 
            action_s_1 = np.asarray( [np.random.choice(s_action_size)] )
            # Combine actions
            actions_g = np.array( (action_g_0, action_g_1) )                                    
            actions_s = np.array( (action_s_0, action_s_1) )
            actions = dict( zip( [g_brain_name, s_brain_name], [actions_g, actions_s] ) )
            
            env_info = env.step(actions)                                                
            g_next_states = env_info[g_brain_name].vector_observations         
            s_next_states = env_info[s_brain_name].vector_observations
            
            g_rewards = env_info[g_brain_name].rewards
            s_rewards = env_info[s_brain_name].rewards
            g_scores += g_rewards
            s_scores += s_rewards
            
            ball_reward_val += ball_reward(s_states[0])
            
            done = np.any(env_info[g_brain_name].local_done)
            print(env_info[g_brain_name].text_observations)
            print(env_info[g_brain_name].visual_observations)
            
            g_agent.step(g_states[0], action_g_0, g_rewards[0], 
                         g_next_states[0], done)
            s_agent.step(s_states[0], action_s_0, s_rewards[0] + ball_reward(s_states[0]), # adding ball reward
                         s_next_states[0], done)

            if done:
                break
                
            g_states = g_next_states
            s_states = s_next_states
                
        goalie_loss = g_agent.learn(g_agent.memory.sample(), 0.99) # discount = 0.99
        striker_loss = s_agent.learn(s_agent.memory.sample(), 0.99) # discount = 0.99 
        
        g_losses.append(goalie_loss.item())
        g_losses_window.append(goalie_loss.item())
        s_losses.append(striker_loss.item())
        s_losses_window.append(striker_loss.item())
        
        score = g_scores[0] + s_scores[0]
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}\t Goalie Loss:' \
                  '{:.5f}\t Striker Loss: {:.5f}' \
                  '\t Ball Reward: {:.2f}'.format(i_episode, \
                                                  np.mean(scores_window), \
                                                  np.mean(g_losses_window), \
                                                  np.mean(s_losses_window), \
                                                  ball_reward_val), end="")
        #print(s_states[0][0:56])
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}\t Goalie Loss:' \
                  '{:.5f}\t Striker Loss: {:.5f}\n' \
                  '\t Ball Reward: {:.2f}'.format(i_episode, \
                                                  np.mean(scores_window), \
                                                  np.mean(g_losses_window), \
                                                  np.mean(s_losses_window), \
                                                  ball_reward_val))
            torch.save(g_agent.qnetwork_local.state_dict(), 'checkpoint_goalie.pth')
            torch.save(s_agent.qnetwork_local.state_dict(), 'checkpoint_striker.pth')
    return scores

# %%
# set the goalie brain
g_brain_name = env.brain_names[0]
g_brain = env.brains[g_brain_name]

# set the striker brain
s_brain_name = env.brain_names[1]
s_brain = env.brains[s_brain_name]

# %%
# reset the environment
env_info = env.reset(train_mode=True)

# number of agents 
num_g_agents = len(env_info[g_brain_name].agents)
num_s_agents = len(env_info[s_brain_name].agents)

# number of actions
g_action_size = g_brain.vector_action_space_size
s_action_size = s_brain.vector_action_space_size

# examine the state space 
g_states = env_info[g_brain_name].vector_observations
g_state_size = g_states.shape[1]
s_states = env_info[s_brain_name].vector_observations
s_state_size = s_states.shape[1]

g_agent = Agent(state_size=g_state_size, action_size=g_action_size, seed=0)
s_agent = Agent(state_size=s_state_size, action_size=s_action_size, seed=0)

# %%
n_episodes = 5000
n_episodes = 5
max_t = 100000
eps_start = 1.0
eps_end = 0.1
eps_decay = 0.9995

GOALIE = 'goalie_dqn.pth'
STRIKER = 'striker_dqn.pth'
g_agent.qnetwork_local.load (GOALIE )
s_agent.qnetwork_local.load( STRIKER )

# Train
eps_start = 0.1
eps_end = 0.1
scores = dqn(n_episodes, max_t, eps_start, eps_end, eps_decay)

# %%
# Load trained agents and run
g_agent_blue = Agent(state_size=g_state_size, action_size=g_action_size, seed=0)
s_agent_blue = Agent(state_size=s_state_size, action_size=s_action_size, seed=0)
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
goalie_actor_model = ActorModel( g_state_size, g_action_size ).to(DEVICE)
striker_actor_model = ActorModel( s_state_size, s_action_size ).to(DEVICE)
N_STEP = 8

GOALIE_red = 'goalie_dqn_run.pth'
STRIKER_red = 'striker_dqn_run.pth'
g_agent_red = PpoAgent( DEVICE, 0, goalie_actor_model, N_STEP )
s_agent_red = PpoAgent( DEVICE, 0, striker_actor_model, N_STEP )

GOALIE_blue = 'goalie_dqn_mod.pth'
STRIKER_blue = 'striker_dqn_mod.pth'
g_agent_blue.qnetwork_local.load (GOALIE_blue )
s_agent_blue.qnetwork_local.load( STRIKER_blue )

# %%
team_red_window_score = []
team_red_window_score_wins = []

team_blue_window_score = []
team_blue_window_score_wins = []

draws = []

for i in range(500):                                       # play game for 2 episodes
    env_info = env.reset(train_mode=True)                  # reset the environment    
    g_states = env_info[g_brain_name].vector_observations  # get initial state (goalies)
    s_states = env_info[s_brain_name].vector_observations  # get initial state (strikers)
    g_scores = np.zeros(num_g_agents)                      # initialize the score (goalies)
    s_scores = np.zeros(num_s_agents)                      # initialize the score (strikers)
    while True:
        action_g_0, _ = g_agent_red.act( g_states[0] )
        action_s_0, _ = s_agent_red.act( s_states[0] )
        action_g_1 = np.asarray( [np.random.choice(g_action_size)] ) 
        action_s_1 = np.asarray( [np.random.choice(s_action_size)] )

        # Combine actions
        actions_g = np.array( (action_g_0, action_g_1) )                                    
        actions_s = np.array( (action_s_0, action_s_1) )
        actions = dict( zip( [g_brain_name, s_brain_name], [actions_g, actions_s] ) )

        env_info = env.step(actions)                       
        
        # get next states
        g_next_states = env_info[g_brain_name].vector_observations         
        s_next_states = env_info[s_brain_name].vector_observations
        
        # get reward and update scores
        g_rewards = env_info[g_brain_name].rewards  
        s_rewards = env_info[s_brain_name].rewards
        g_scores += g_rewards
        s_scores += s_rewards
        
        # check if episode finished
        done = np.any(env_info[g_brain_name].local_done)  
        
        # roll over states to next time step
        g_states = g_next_states
        s_states = s_next_states
        
        # exit loop if episode finished
        if done:                                           
            break
    team_red_score = g_scores[0] + s_scores[0]
    team_red_window_score.append( team_red_score )
    team_red_window_score_wins.append( 1 if team_red_score > 0 else 0)        

    team_blue_score = g_scores[1] + s_scores[1]
    team_blue_window_score.append( team_blue_score )
    team_blue_window_score_wins.append( 1 if team_blue_score > 0 else 0 )

    draws.append( team_red_score == team_blue_score )
    print('Scores from episode {}: {} (goalies), {} (strikers)'.format(i+1, g_scores, s_scores))

print('Red Wins: \t{} \tScore: \t{:.5f} \tAvg: \t{:.2f} \tDraws: \t{}'.format( \
                  np.count_nonzero(team_red_window_score_wins), team_red_score, \
                  np.sum(team_red_window_score), np.count_nonzero(draws) ))

env.close()
# Out:
# D:\Anaconda\envs\internship\lib\site-packages\ipykernel_launcher.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# D:\Anaconda\envs\internship\lib\site-packages\ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Scores from episode 1: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 2: [-0.61166672  0.48833334] (goalies), [-0.48833334  0.61166672] (strikers)
# Scores from episode 3: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 4: [ 0.255 -0.845] (goalies), [ 0.845 -0.255] (strikers)
# Scores from episode 5: [ 0.65166667 -0.44833338] (goalies), [ 0.44833338 -0.65166667] (strikers)
# Scores from episode 6: [ 0.65333335 -0.44666665] (goalies), [ 0.44666665 -0.65333335] (strikers)
# Scores from episode 7: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 8: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 9: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 10: [-0.955  0.145] (goalies), [-0.145  0.955] (strikers)
# Scores from episode 11: [ 0.59000001 -0.51000005] (goalies), [ 0.51000005 -0.59000001] (strikers)
# Scores from episode 12: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 13: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 14: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 15: [ 0.33666667 -0.76333333] (goalies), [ 0.76333333 -0.33666667] (strikers)
# Scores from episode 16: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 17: [-0.67333339  0.42666667] (goalies), [-0.42666667  0.67333339] (strikers)
# Scores from episode 18: [ 0.69166667 -0.40833344] (goalies), [ 0.40833344 -0.69166667] (strikers)
# Scores from episode 19: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 20: [-0.29166665  0.80833335] (goalies), [-0.80833335  0.29166665] (strikers)
# Scores from episode 21: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 22: [-0.72833339  0.37166667] (goalies), [-0.37166667  0.72833339] (strikers)
# Scores from episode 23: [ 0.17166667 -0.92833333] (goalies), [ 0.92833333 -0.17166667] (strikers)
# Scores from episode 24: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 25: [ 0.78833334 -0.31166677] (goalies), [ 0.31166677 -0.78833334] (strikers)
# Scores from episode 26: [ 0.42833334 -0.67166666] (goalies), [ 0.67166666 -0.42833334] (strikers)
# Scores from episode 27: [-0.51499999  0.58500001] (goalies), [-0.58500001  0.51499999] (strikers)
# Scores from episode 28: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 29: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 30: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 31: [-0.71666672  0.38333334] (goalies), [-0.38333334  0.71666672] (strikers)
# Scores from episode 32: [ 0.25833334 -0.84166672] (goalies), [ 0.84166672 -0.25833334] (strikers)
# Scores from episode 33: [ 0.99666668 -0.10333337] (goalies), [ 0.10333337 -0.99666668] (strikers)
# Scores from episode 34: [-0.30833344  0.79166668] (goalies), [-0.79166668  0.30833344] (strikers)
# Scores from episode 35: [ 0.14166667 -0.95833339] (goalies), [ 0.95833339 -0.14166667] (strikers)
# Scores from episode 36: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 37: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 38: [-0.49166666  0.60833335] (goalies), [-0.60833335  0.49166666] (strikers)
# Scores from episode 39: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 40: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 41: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 42: [ 0.155 -0.945] (goalies), [ 0.945 -0.155] (strikers)
# Scores from episode 43: [-0.91000012  0.18999999] (goalies), [-0.18999999  0.91000012] (strikers)
# Scores from episode 44: [ 0.91500002 -0.18499998] (goalies), [ 0.18499998 -0.91500002] (strikers)
# Scores from episode 45: [-0.23166671  0.86833335] (goalies), [-0.86833335  0.23166671] (strikers)
# Scores from episode 46: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 47: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 48: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 49: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 50: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 51: [-0.03666664  1.06333336] (goalies), [-1.06333336  0.03666664] (strikers)
# Scores from episode 52: [-0.68833339  0.41166667] (goalies), [-0.41166667  0.68833339] (strikers)
# Scores from episode 53: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 54: [-0.58333338  0.51666667] (goalies), [-0.51666667  0.58333338] (strikers)
# Scores from episode 55: [ 0.335      -0.76500012] (goalies), [ 0.76500012 -0.335     ] (strikers)
# Scores from episode 56: [-0.81833339  0.28166666] (goalies), [-0.28166666  0.81833339] (strikers)
# Scores from episode 57: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 58: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 59: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 60: [-0.70166678  0.39833333] (goalies), [-0.39833333  0.70166678] (strikers)
# Scores from episode 61: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 62: [ 0.25166667 -0.84833333] (goalies), [ 0.84833333 -0.25166667] (strikers)
# Scores from episode 63: [ 0.20666667 -0.89333333] (goalies), [ 0.89333333 -0.20666667] (strikers)
# Scores from episode 64: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 65: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 66: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 67: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 68: [-0.26833338  0.83166668] (goalies), [-0.83166668  0.26833338] (strikers)
# Scores from episode 69: [ 0.49500001 -0.60500005] (goalies), [ 0.60500005 -0.49500001] (strikers)
# Scores from episode 70: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 71: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 72: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 73: [ 0.73333335 -0.36666665] (goalies), [ 0.36666665 -0.73333335] (strikers)
# Scores from episode 74: [ 0.79000001 -0.3100001 ] (goalies), [ 0.3100001  -0.79000001] (strikers)
# Scores from episode 75: [-0.57833338  0.52166667] (goalies), [-0.52166667  0.57833338] (strikers)
# Scores from episode 76: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 77: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 78: [ 0.18499999 -0.91500006] (goalies), [ 0.91500006 -0.18499999] (strikers)
# Scores from episode 79: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 80: [ 0.44166667 -0.65833333] (goalies), [ 0.65833333 -0.44166667] (strikers)
# Scores from episode 81: [-0.94333339  0.15666667] (goalies), [-0.15666667  0.94333339] (strikers)
# Scores from episode 82: [ 0.48166668 -0.61833333] (goalies), [ 0.61833333 -0.48166668] (strikers)
# Scores from episode 83: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 84: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 85: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 86: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 87: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 88: [ 0.93666669 -0.16333331] (goalies), [ 0.16333331 -0.93666669] (strikers)
# Scores from episode 89: [-0.63500005  0.465     ] (goalies), [-0.465       0.63500005] (strikers)
# Scores from episode 90: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 91: [ 0.58166668 -0.51833332] (goalies), [ 0.51833332 -0.58166668] (strikers)
# Scores from episode 92: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 93: [ 0.3        -0.80000006] (goalies), [ 0.80000006 -0.3       ] (strikers)
# Scores from episode 94: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 95: [ 0.75500002 -0.34500005] (goalies), [ 0.34500005 -0.75500002] (strikers)
# Scores from episode 96: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 97: [-0.80500006  0.295     ] (goalies), [-0.295       0.80500006] (strikers)
# Scores from episode 98: [-0.13333331  0.96666669] (goalies), [-0.96666669  0.13333331] (strikers)
# Scores from episode 99: [ 0.395      -0.70500011] (goalies), [ 0.70500011 -0.395     ] (strikers)
# Scores from episode 100: [ 0.94833335 -0.15166671] (goalies), [ 0.15166671 -0.94833335] (strikers)
# Scores from episode 101: [ 0.235      -0.86500006] (goalies), [ 0.86500006 -0.235     ] (strikers)
# Scores from episode 102: [-0.845  0.255] (goalies), [-0.255  0.845] (strikers)
# Scores from episode 103: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 104: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 105: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 106: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 107: [-0.84  0.26] (goalies), [-0.26  0.84] (strikers)
# Scores from episode 108: [-0.44500011  0.65500001] (goalies), [-0.65500001  0.44500011] (strikers)
# Scores from episode 109: [-0.42500005  0.67500001] (goalies), [-0.67500001  0.42500005] (strikers)
# Scores from episode 110: [ 0.48666667 -0.61333344] (goalies), [ 0.61333344 -0.48666667] (strikers)
# Scores from episode 111: [-0.76333339  0.33666667] (goalies), [-0.33666667  0.76333339] (strikers)
# Scores from episode 112: [ 0.78166668 -0.31833338] (goalies), [ 0.31833338 -0.78166668] (strikers)
# Scores from episode 113: [-0.52833344  0.57166667] (goalies), [-0.57166667  0.52833344] (strikers)
# Scores from episode 114: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 115: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 116: [-0.71666672  0.38333333] (goalies), [-0.38333333  0.71666672] (strikers)
# Scores from episode 117: [ 0.12833333 -0.97166667] (goalies), [ 0.97166667 -0.12833333] (strikers)
# Scores from episode 118: [ 1.01666669 -0.08333331] (goalies), [ 0.08333331 -1.01666669] (strikers)
# Scores from episode 119: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 120: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 121: [ 0.32333333 -0.77666672] (goalies), [ 0.77666672 -0.32333333] (strikers)
# Scores from episode 122: [-0.48000011  0.62000001] (goalies), [-0.62000001  0.48000011] (strikers)
# Scores from episode 123: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 124: [ 1.02666669 -0.07333331] (goalies), [ 0.07333331 -1.02666669] (strikers)
# Scores from episode 125: [ 0.71500001 -0.38500011] (goalies), [ 0.38500011 -0.71500001] (strikers)
# Scores from episode 126: [ 0.88166669 -0.21833332] (goalies), [ 0.21833332 -0.88166669] (strikers)
# Scores from episode 127: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 128: [ 0.79833335 -0.30166665] (goalies), [ 0.30166665 -0.79833335] (strikers)
# Scores from episode 129: [ 0.14333333 -0.95666673] (goalies), [ 0.95666673 -0.14333333] (strikers)
# Scores from episode 130: [ 0.295      -0.80500006] (goalies), [ 0.80500006 -0.295     ] (strikers)
# Scores from episode 131: [-0.52333344  0.57666667] (goalies), [-0.57666667  0.52333344] (strikers)
# Scores from episode 132: [-0.0466667   1.05333335] (goalies), [-1.05333335  0.0466667 ] (strikers)
# Scores from episode 133: [ 0.35833333 -0.74166678] (goalies), [ 0.74166678 -0.35833333] (strikers)
# Scores from episode 134: [ 0.37333333 -0.72666672] (goalies), [ 0.72666672 -0.37333333] (strikers)
# Scores from episode 135: [ 0.40500001 -0.69499999] (goalies), [ 0.69499999 -0.40500001] (strikers)
# Scores from episode 136: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 137: [ 0.23833333 -0.86166672] (goalies), [ 0.86166672 -0.23833333] (strikers)
# Scores from episode 138: [ 0.24166667 -0.85833333] (goalies), [ 0.85833333 -0.24166667] (strikers)
# Scores from episode 139: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 140: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 141: [ 0.35500001 -0.74500006] (goalies), [ 0.74500006 -0.35500001] (strikers)
# Scores from episode 142: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 143: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 144: [ 0.68000001 -0.42000011] (goalies), [ 0.42000011 -0.68000001] (strikers)
# Scores from episode 145: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 146: [ 0.81500002 -0.28499998] (goalies), [ 0.28499998 -0.81500002] (strikers)
# Scores from episode 147: [-0.27499998  0.82500002] (goalies), [-0.82500002  0.27499998] (strikers)
# Scores from episode 148: [ 0.81833335 -0.28166671] (goalies), [ 0.28166671 -0.81833335] (strikers)
# Scores from episode 149: [ 0.81000001 -0.2900001 ] (goalies), [ 0.2900001  -0.81000001] (strikers)
# Scores from episode 150: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 151: [-0.68666672  0.41333334] (goalies), [-0.41333334  0.68666672] (strikers)
# Scores from episode 152: [ 0.41500001 -0.68499999] (goalies), [ 0.68499999 -0.41500001] (strikers)
# Scores from episode 153: [ 0.90666668 -0.19333338] (goalies), [ 0.19333338 -0.90666668] (strikers)
# Scores from episode 154: [-0.36000011  0.74000001] (goalies), [-0.74000001  0.36000011] (strikers)
# Scores from episode 155: [ 0.32833333 -0.77166672] (goalies), [ 0.77166672 -0.32833333] (strikers)
# Scores from episode 156: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 157: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 158: [-0.16666671  0.93333335] (goalies), [-0.93333335  0.16666671] (strikers)
# Scores from episode 159: [-0.91833345  0.18166666] (goalies), [-0.18166666  0.91833345] (strikers)
# Scores from episode 160: [-0.61333344  0.48666667] (goalies), [-0.48666667  0.61333344] (strikers)
# Scores from episode 161: [ 0.56166668 -0.53833338] (goalies), [ 0.53833338 -0.56166668] (strikers)
# Scores from episode 162: [ 0.71833335 -0.38166665] (goalies), [ 0.38166665 -0.71833335] (strikers)
# Scores from episode 163: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 164: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 165: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 166: [-0.88833333  0.21166667] (goalies), [-0.21166667  0.88833333] (strikers)
# Scores from episode 167: [-0.72000011  0.38      ] (goalies), [-0.38        0.72000011] (strikers)
# Scores from episode 168: [ 0.98833335 -0.11166665] (goalies), [ 0.11166665 -0.98833335] (strikers)
# Scores from episode 169: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 170: [-0.34666665  0.75333335] (goalies), [-0.75333335  0.34666665] (strikers)
# Scores from episode 171: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 172: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 173: [-0.20999998  0.89000002] (goalies), [-0.89000002  0.20999998] (strikers)
# Scores from episode 174: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 175: [-0.87  0.23] (goalies), [-0.23  0.87] (strikers)
# Scores from episode 176: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 177: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 178: [-0.33000005  0.77000002] (goalies), [-0.77000002  0.33000005] (strikers)
# Scores from episode 179: [-0.73666666  0.36333334] (goalies), [-0.36333334  0.73666666] (strikers)
# Scores from episode 180: [-0.77000006  0.33      ] (goalies), [-0.33        0.77000006] (strikers)
# Scores from episode 181: [-0.94833333  0.15166667] (goalies), [-0.15166667  0.94833333] (strikers)
# Scores from episode 182: [ 0.29666667 -0.80333339] (goalies), [ 0.80333339 -0.29666667] (strikers)
# Scores from episode 183: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 184: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 185: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 186: [-0.15999998  0.94000002] (goalies), [-0.94000002  0.15999998] (strikers)
# Scores from episode 187: [ 0.31833334 -0.78166666] (goalies), [ 0.78166666 -0.31833334] (strikers)
# Scores from episode 188: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 189: [-0.50500011  0.595     ] (goalies), [-0.595       0.50500011] (strikers)
# Scores from episode 190: [-0.21499998  0.88500002] (goalies), [-0.88500002  0.21499998] (strikers)
# Scores from episode 191: [ 0.64166667 -0.45833344] (goalies), [ 0.45833344 -0.64166667] (strikers)
# Scores from episode 192: [-0.76500006  0.33500001] (goalies), [-0.33500001  0.76500006] (strikers)
# Scores from episode 193: [ 0.18999999 -0.91000012] (goalies), [ 0.91000012 -0.18999999] (strikers)
# Scores from episode 194: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 195: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 196: [-0.865  0.235] (goalies), [-0.235  0.865] (strikers)
# Scores from episode 197: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 198: [-0.08000004  1.02000001] (goalies), [-1.02000001  0.08000004] (strikers)
# Scores from episode 199: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 200: [ 0.49166668 -0.60833339] (goalies), [ 0.60833339 -0.49166668] (strikers)
# Scores from episode 201: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 202: [-0.28000004  0.82000002] (goalies), [-0.82000002  0.28000004] (strikers)
# Scores from episode 203: [ 0.72500001 -0.37500005] (goalies), [ 0.37500005 -0.72500001] (strikers)
# Scores from episode 204: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 205: [ 0.78000002 -0.31999999] (goalies), [ 0.31999999 -0.78000002] (strikers)
# Scores from episode 206: [ 0.14499999 -0.95500012] (goalies), [ 0.95500012 -0.14499999] (strikers)
# Scores from episode 207: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 208: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 209: [-0.43166665  0.66833335] (goalies), [-0.66833335  0.43166665] (strikers)
# Scores from episode 210: [ 0.53000001 -0.57000005] (goalies), [ 0.57000005 -0.53000001] (strikers)
# Scores from episode 211: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 212: [-0.36499999  0.73500002] (goalies), [-0.73500002  0.36499999] (strikers)
# Scores from episode 213: [ 0.37666667 -0.72333333] (goalies), [ 0.72333333 -0.37666667] (strikers)
# Scores from episode 214: [ 0.56333334 -0.53666666] (goalies), [ 0.53666666 -0.56333334] (strikers)
# Scores from episode 215: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 216: [-0.53166672  0.56833334] (goalies), [-0.56833334  0.53166672] (strikers)
# Scores from episode 217: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 218: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 219: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 220: [ 0.45000001 -0.64999999] (goalies), [ 0.64999999 -0.45000001] (strikers)
# Scores from episode 221: [ 0.92500002 -0.17500004] (goalies), [ 0.17500004 -0.92500002] (strikers)
# Scores from episode 222: [ 1.02833336 -0.07166665] (goalies), [ 0.07166665 -1.02833336] (strikers)
# Scores from episode 223: [ 0.32333333 -0.77666678] (goalies), [ 0.77666678 -0.32333333] (strikers)
# Scores from episode 224: [-0.06333331  1.03666669] (goalies), [-1.03666669  0.06333331] (strikers)
# Scores from episode 225: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 226: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 227: [-0.23333344  0.86666668] (goalies), [-0.86666668  0.23333344] (strikers)
# Scores from episode 228: [-0.07333331  1.02666669] (goalies), [-1.02666669  0.07333331] (strikers)
# Scores from episode 229: [ 1.09333336 -0.00666664] (goalies), [ 0.00666664 -1.09333336] (strikers)
# Scores from episode 230: [-0.49833332  0.60166668] (goalies), [-0.60166668  0.49833332] (strikers)
# Scores from episode 231: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 232: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 233: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 234: [ 1.08166668 -0.01833343] (goalies), [ 0.01833343 -1.08166668] (strikers)
# Scores from episode 235: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 236: [-0.57500005  0.52500001] (goalies), [-0.52500001  0.57500005] (strikers)
# Scores from episode 237: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 238: [-0.66833333  0.43166667] (goalies), [-0.43166667  0.66833333] (strikers)
# Scores from episode 239: [-0.75833339  0.34166666] (goalies), [-0.34166666  0.75833339] (strikers)
# Scores from episode 240: [ 0.89166669 -0.20833332] (goalies), [ 0.20833332 -0.89166669] (strikers)
# Scores from episode 241: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 242: [ 0.19666667 -0.90333333] (goalies), [ 0.90333333 -0.19666667] (strikers)
# Scores from episode 243: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 244: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 245: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 246: [-0.87333339  0.22666666] (goalies), [-0.22666666  0.87333339] (strikers)
# Scores from episode 247: [-0.31166671  0.78833334] (goalies), [-0.78833334  0.31166671] (strikers)
# Scores from episode 248: [-0.51000005  0.59000001] (goalies), [-0.59000001  0.51000005] (strikers)
# Scores from episode 249: [ 0.29 -0.81] (goalies), [ 0.81 -0.29] (strikers)
# Scores from episode 250: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 251: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 252: [ 0.33       -0.77000006] (goalies), [ 0.77000006 -0.33      ] (strikers)
# Scores from episode 253: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 254: [ 0.44       -0.66000011] (goalies), [ 0.66000011 -0.44      ] (strikers)
# Scores from episode 255: [-0.49833338  0.60166668] (goalies), [-0.60166668  0.49833338] (strikers)
# Scores from episode 256: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 257: [-0.83333339  0.26666666] (goalies), [-0.26666666  0.83333339] (strikers)
# Scores from episode 258: [ 0.27666667 -0.82333339] (goalies), [ 0.82333339 -0.27666667] (strikers)
# Scores from episode 259: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 260: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 261: [-0.34999999  0.75000002] (goalies), [-0.75000002  0.34999999] (strikers)
# Scores from episode 262: [-0.64333345  0.45666667] (goalies), [-0.45666667  0.64333345] (strikers)
# Scores from episode 263: [-0.72666672  0.37333333] (goalies), [-0.37333333  0.72666672] (strikers)
# Scores from episode 264: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 265: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 266: [-0.40166665  0.69833335] (goalies), [-0.69833335  0.40166665] (strikers)
# Scores from episode 267: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 268: [ 0.37333333 -0.72666678] (goalies), [ 0.72666678 -0.37333333] (strikers)
# Scores from episode 269: [ 0.39833333 -0.70166672] (goalies), [ 0.70166672 -0.39833333] (strikers)
# Scores from episode 270: [ 0.39       -0.71000011] (goalies), [ 0.71000011 -0.39      ] (strikers)
# Scores from episode 271: [ 0.80166668 -0.29833338] (goalies), [ 0.29833338 -0.80166668] (strikers)
# Scores from episode 272: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 273: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 274: [ 0.94500001 -0.1550001 ] (goalies), [ 0.1550001  -0.94500001] (strikers)
# Scores from episode 275: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 276: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 277: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 278: [-0.55666666  0.54333334] (goalies), [-0.54333334  0.55666666] (strikers)
# Scores from episode 279: [-0.59166672  0.50833334] (goalies), [-0.50833334  0.59166672] (strikers)
# Scores from episode 280: [ 0.30333334 -0.79666666] (goalies), [ 0.79666666 -0.30333334] (strikers)
# Scores from episode 281: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 282: [ 0.40833334 -0.69166672] (goalies), [ 0.69166672 -0.40833334] (strikers)
# Scores from episode 283: [ 0.48000001 -0.62000005] (goalies), [ 0.62000005 -0.48000001] (strikers)
# Scores from episode 284: [ 0.21333334 -0.88666673] (goalies), [ 0.88666673 -0.21333334] (strikers)
# Scores from episode 285: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 286: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 287: [ 0.79500001 -0.3050001 ] (goalies), [ 0.3050001  -0.79500001] (strikers)
# Scores from episode 288: [-0.24999998  0.85000002] (goalies), [-0.85000002  0.24999998] (strikers)
# Scores from episode 289: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 290: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 291: [-0.0316667   1.06833335] (goalies), [-1.06833335  0.0316667 ] (strikers)
# Scores from episode 292: [-0.84333333  0.25666667] (goalies), [-0.25666667  0.84333333] (strikers)
# Scores from episode 293: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 294: [ 0.84000001 -0.2600001 ] (goalies), [ 0.2600001  -0.84000001] (strikers)
# Scores from episode 295: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 296: [ 0.35833333 -0.74166672] (goalies), [ 0.74166672 -0.35833333] (strikers)
# Scores from episode 297: [ 0.45500001 -0.64499999] (goalies), [ 0.64499999 -0.45500001] (strikers)
# Scores from episode 298: [-0.61333333  0.48666668] (goalies), [-0.48666668  0.61333333] (strikers)
# Scores from episode 299: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 300: [ 0.17999999 -0.92000012] (goalies), [ 0.92000012 -0.17999999] (strikers)
# Scores from episode 301: [ 0.91666669 -0.18333337] (goalies), [ 0.18333337 -0.91666669] (strikers)
# Scores from episode 302: [ 0.57166668 -0.52833332] (goalies), [ 0.52833332 -0.57166668] (strikers)
# Scores from episode 303: [-0.61166672  0.48833334] (goalies), [-0.48833334  0.61166672] (strikers)
# Scores from episode 304: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 305: [ 0.87833334 -0.22166677] (goalies), [ 0.22166677 -0.87833334] (strikers)
# Scores from episode 306: [-0.68166678  0.41833333] (goalies), [-0.41833333  0.68166678] (strikers)
# Scores from episode 307: [ 0.14 -0.96] (goalies), [ 0.96 -0.14] (strikers)
# Scores from episode 308: [-0.2600001   0.84000001] (goalies), [-0.84000001  0.2600001 ] (strikers)
# Scores from episode 309: [ 0.29833333 -0.80166678] (goalies), [ 0.80166678 -0.29833333] (strikers)
# Scores from episode 310: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 311: [-0.03833343  1.06166668] (goalies), [-1.06166668  0.03833343] (strikers)
# Scores from episode 312: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 313: [-0.75166666  0.34833334] (goalies), [-0.34833334  0.75166666] (strikers)
# Scores from episode 314: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 315: [ 0.83666668 -0.26333344] (goalies), [ 0.26333344 -0.83666668] (strikers)
# Scores from episode 316: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 317: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 318: [ 0.40166667 -0.69833339] (goalies), [ 0.69833339 -0.40166667] (strikers)
# Scores from episode 319: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 320: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 321: [ 0.50833334 -0.59166666] (goalies), [ 0.59166666 -0.50833334] (strikers)
# Scores from episode 322: [ 0.43000001 -0.66999999] (goalies), [ 0.66999999 -0.43000001] (strikers)
# Scores from episode 323: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 324: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 325: [ 0.48500001 -0.61499999] (goalies), [ 0.61499999 -0.48500001] (strikers)
# Scores from episode 326: [-0.85666666  0.24333334] (goalies), [-0.24333334  0.85666666] (strikers)
# Scores from episode 327: [ 0.235 -0.865] (goalies), [ 0.865 -0.235] (strikers)
# Scores from episode 328: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 329: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 330: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 331: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 332: [-0.33666665  0.76333335] (goalies), [-0.76333335  0.33666665] (strikers)
# Scores from episode 333: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 334: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 335: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 336: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 337: [ 0.92833335 -0.17166665] (goalies), [ 0.17166665 -0.92833335] (strikers)
# Scores from episode 338: [-0.83833333  0.26166667] (goalies), [-0.26166667  0.83833333] (strikers)
# Scores from episode 339: [-0.03666664  1.06333336] (goalies), [-1.06333336  0.03666664] (strikers)
# Scores from episode 340: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 341: [ 0.27333334 -0.82666666] (goalies), [ 0.82666666 -0.27333334] (strikers)
# Scores from episode 342: [-0.39166677  0.70833334] (goalies), [-0.70833334  0.39166677] (strikers)
# Scores from episode 343: [ 0.18       -0.92000006] (goalies), [ 0.92000006 -0.18      ] (strikers)
# Scores from episode 344: [-0.53999999  0.56000001] (goalies), [-0.56000001  0.53999999] (strikers)
# Scores from episode 345: [-0.39166671  0.70833335] (goalies), [-0.70833335  0.39166671] (strikers)
# Scores from episode 346: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 347: [ 0.38666667 -0.71333333] (goalies), [ 0.71333333 -0.38666667] (strikers)
# Scores from episode 348: [ 0.31500001 -0.785     ] (goalies), [ 0.785      -0.31500001] (strikers)
# Scores from episode 349: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 350: [ 0.30833334 -0.79166666] (goalies), [ 0.79166666 -0.30833334] (strikers)
# Scores from episode 351: [ 0.16666667 -0.93333339] (goalies), [ 0.93333339 -0.16666667] (strikers)
# Scores from episode 352: [-0.52999999  0.57000001] (goalies), [-0.57000001  0.52999999] (strikers)
# Scores from episode 353: [-0.59999999  0.50000001] (goalies), [-0.50000001  0.59999999] (strikers)
# Scores from episode 354: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 355: [-0.0066667   1.09333335] (goalies), [-1.09333335  0.0066667 ] (strikers)
# Scores from episode 356: [-0.58166672  0.51833334] (goalies), [-0.51833334  0.58166672] (strikers)
# Scores from episode 357: [ 0.40666667 -0.69333333] (goalies), [ 0.69333333 -0.40666667] (strikers)
# Scores from episode 358: [ 0.32833333 -0.77166672] (goalies), [ 0.77166672 -0.32833333] (strikers)
# Scores from episode 359: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 360: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 361: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 362: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 363: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 364: [ 0.91333335 -0.18666665] (goalies), [ 0.18666665 -0.91333335] (strikers)
# Scores from episode 365: [ 0.86333335 -0.23666671] (goalies), [ 0.23666671 -0.86333335] (strikers)
# Scores from episode 366: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 367: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 368: [ 0.89666669 -0.20333332] (goalies), [ 0.20333332 -0.89666669] (strikers)
# Scores from episode 369: [ 0.83333334 -0.26666677] (goalies), [ 0.26666677 -0.83333334] (strikers)
# Scores from episode 370: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 371: [ 0.89500002 -0.20499998] (goalies), [ 0.20499998 -0.89500002] (strikers)
# Scores from episode 372: [ 0.66500001 -0.43499999] (goalies), [ 0.43499999 -0.66500001] (strikers)
# Scores from episode 373: [-0.72333339  0.37666667] (goalies), [-0.37666667  0.72333339] (strikers)
# Scores from episode 374: [ 0.19666666 -0.90333339] (goalies), [ 0.90333339 -0.19666666] (strikers)
# Scores from episode 375: [ 0.59833334 -0.50166672] (goalies), [ 0.50166672 -0.59833334] (strikers)
# Scores from episode 376: [-0.46333338  0.63666667] (goalies), [-0.63666667  0.46333338] (strikers)
# Scores from episode 377: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 378: [ 0.30333334 -0.79666666] (goalies), [ 0.79666666 -0.30333334] (strikers)
# Scores from episode 379: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 380: [-0.44833338  0.65166667] (goalies), [-0.65166667  0.44833338] (strikers)
# Scores from episode 381: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 382: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 383: [-0.58666672  0.51333334] (goalies), [-0.51333334  0.58666672] (strikers)
# Scores from episode 384: [-0.89833333  0.20166667] (goalies), [-0.20166667  0.89833333] (strikers)
# Scores from episode 385: [-0.38500005  0.71500001] (goalies), [-0.71500001  0.38500005] (strikers)
# Scores from episode 386: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 387: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 388: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 389: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 390: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 391: [ 0.62166667 -0.47833344] (goalies), [ 0.47833344 -0.62166667] (strikers)
# Scores from episode 392: [ 0.265      -0.83500006] (goalies), [ 0.83500006 -0.265     ] (strikers)
# Scores from episode 393: [-0.0316667   1.06833336] (goalies), [-1.06833336  0.0316667 ] (strikers)
# Scores from episode 394: [-0.78333345  0.31666666] (goalies), [-0.31666666  0.78333345] (strikers)
# Scores from episode 395: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 396: [ 0.38       -0.72000005] (goalies), [ 0.72000005 -0.38      ] (strikers)
# Scores from episode 397: [ 0.47833333 -0.62166672] (goalies), [ 0.62166672 -0.47833333] (strikers)
# Scores from episode 398: [-0.31166671  0.78833334] (goalies), [-0.78833334  0.31166671] (strikers)
# Scores from episode 399: [ 0.17166667 -0.92833333] (goalies), [ 0.92833333 -0.17166667] (strikers)
# Scores from episode 400: [-0.45666666  0.64333335] (goalies), [-0.64333335  0.45666666] (strikers)
# Scores from episode 401: [ 0.34666667 -0.75333333] (goalies), [ 0.75333333 -0.34666667] (strikers)
# Scores from episode 402: [-0.51000011  0.59      ] (goalies), [-0.59        0.51000011] (strikers)
# Scores from episode 403: [-0.32500004  0.77500002] (goalies), [-0.77500002  0.32500004] (strikers)
# Scores from episode 404: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 405: [ 0.24666667 -0.85333333] (goalies), [ 0.85333333 -0.24666667] (strikers)
# Scores from episode 406: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 407: [-0.86666667  0.23333334] (goalies), [-0.23333334  0.86666667] (strikers)
# Scores from episode 408: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 409: [-0.10666671  0.99333335] (goalies), [-0.99333335  0.10666671] (strikers)
# Scores from episode 410: [-0.25499998  0.84500002] (goalies), [-0.84500002  0.25499998] (strikers)
# Scores from episode 411: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 412: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 413: [-0.74666672  0.35333334] (goalies), [-0.35333334  0.74666672] (strikers)
# Scores from episode 414: [-0.74333339  0.35666667] (goalies), [-0.35666667  0.74333339] (strikers)
# Scores from episode 415: [ 0.53166668 -0.56833332] (goalies), [ 0.56833332 -0.53166668] (strikers)
# Scores from episode 416: [ 0.72166668 -0.37833338] (goalies), [ 0.37833338 -0.72166668] (strikers)
# Scores from episode 417: [ 0.16333333 -0.93666667] (goalies), [ 0.93666667 -0.16333333] (strikers)
# Scores from episode 418: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 419: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 420: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 421: [ 0.16 -0.94] (goalies), [ 0.94 -0.16] (strikers)
# Scores from episode 422: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 423: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 424: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 425: [-0.10666665  0.99333335] (goalies), [-0.99333335  0.10666665] (strikers)
# Scores from episode 426: [ 0.40833333 -0.69166672] (goalies), [ 0.69166672 -0.40833333] (strikers)
# Scores from episode 427: [-0.10166671  0.99833335] (goalies), [-0.99833335  0.10166671] (strikers)
# Scores from episode 428: [ 0.22 -0.88] (goalies), [ 0.88 -0.22] (strikers)
# Scores from episode 429: [-0.24666671  0.85333335] (goalies), [-0.85333335  0.24666671] (strikers)
# Scores from episode 430: [ 0.35000001 -0.75      ] (goalies), [ 0.75       -0.35000001] (strikers)
# Scores from episode 431: [ 0.77000002 -0.32999999] (goalies), [ 0.32999999 -0.77000002] (strikers)
# Scores from episode 432: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 433: [ 0.74833334 -0.35166677] (goalies), [ 0.35166677 -0.74833334] (strikers)
# Scores from episode 434: [ 0.81500002 -0.28499998] (goalies), [ 0.28499998 -0.81500002] (strikers)
# Scores from episode 435: [-0.94500006  0.155     ] (goalies), [-0.155       0.94500006] (strikers)
# Scores from episode 436: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 437: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 438: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 439: [-0.88500006  0.215     ] (goalies), [-0.215       0.88500006] (strikers)
# Scores from episode 440: [ 0.67666667 -0.42333344] (goalies), [ 0.42333344 -0.67666667] (strikers)
# Scores from episode 441: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 442: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 443: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 444: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 445: [ 0.89000001 -0.2100001 ] (goalies), [ 0.2100001  -0.89000001] (strikers)
# Scores from episode 446: [-0.56333332  0.53666668] (goalies), [-0.53666668  0.56333332] (strikers)
# Scores from episode 447: [-0.02000004  1.08000002] (goalies), [-1.08000002  0.02000004] (strikers)
# Scores from episode 448: [-0.76666666  0.33333334] (goalies), [-0.33333334  0.76666666] (strikers)
# Scores from episode 449: [ 0.49833334 -0.60166672] (goalies), [ 0.60166672 -0.49833334] (strikers)
# Scores from episode 450: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 451: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 452: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 453: [-0.19666677  0.90333335] (goalies), [-0.90333335  0.19666677] (strikers)
# Scores from episode 454: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 455: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 456: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 457: [ 0.20333333 -0.89666673] (goalies), [ 0.89666673 -0.20333333] (strikers)
# Scores from episode 458: [ 0.57833334 -0.52166672] (goalies), [ 0.52166672 -0.57833334] (strikers)
# Scores from episode 459: [-0.64499999  0.45500001] (goalies), [-0.45500001  0.64499999] (strikers)
# Scores from episode 460: [ 0.34833334 -0.75166666] (goalies), [ 0.75166666 -0.34833334] (strikers)
# Scores from episode 461: [-0.3250001   0.77500001] (goalies), [-0.77500001  0.3250001 ] (strikers)
# Scores from episode 462: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 463: [ 0.85000001 -0.2500001 ] (goalies), [ 0.2500001  -0.85000001] (strikers)
# Scores from episode 464: [ 0.44166667 -0.65833333] (goalies), [ 0.65833333 -0.44166667] (strikers)
# Scores from episode 465: [-0.72166666  0.37833334] (goalies), [-0.37833334  0.72166666] (strikers)
# Scores from episode 466: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 467: [ 0.64500001 -0.45500011] (goalies), [ 0.45500011 -0.64500001] (strikers)
# Scores from episode 468: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 469: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 470: [-0.76333333  0.33666667] (goalies), [-0.33666667  0.76333333] (strikers)
# Scores from episode 471: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 472: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 473: [ 0.82166668 -0.27833338] (goalies), [ 0.27833338 -0.82166668] (strikers)
# Scores from episode 474: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 475: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 476: [-0.855  0.245] (goalies), [-0.245  0.855] (strikers)
# Scores from episode 477: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 478: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 479: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 480: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 481: [ 0.44833334 -0.65166666] (goalies), [ 0.65166666 -0.44833334] (strikers)
# Scores from episode 482: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 483: [-0.73666678  0.36333333] (goalies), [-0.36333333  0.73666678] (strikers)
# Scores from episode 484: [-0.91000006  0.18999999] (goalies), [-0.18999999  0.91000006] (strikers)
# Scores from episode 485: [-0.52666672  0.57333334] (goalies), [-0.57333334  0.52666672] (strikers)
# Scores from episode 486: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 487: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 488: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 489: [ 0.20666667 -0.89333339] (goalies), [ 0.89333339 -0.20666667] (strikers)
# Scores from episode 490: [-0.38499999  0.71500001] (goalies), [-0.71500001  0.38499999] (strikers)
# Scores from episode 491: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 492: [-9.66247171e-08  1.10000002e+00] (goalies), [-1.10000002e+00  9.66247171e-08] (strikers)
# Scores from episode 493: [ 0.44833334 -0.65166666] (goalies), [ 0.65166666 -0.44833334] (strikers)
# Scores from episode 494: [ 0.39000001 -0.70999999] (goalies), [ 0.70999999 -0.39000001] (strikers)
# Scores from episode 495: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 496: [ 0.79166668 -0.30833338] (goalies), [ 0.30833338 -0.79166668] (strikers)
# Scores from episode 497: [-0.42333338  0.67666667] (goalies), [-0.67666667  0.42333338] (strikers)
# Scores from episode 498: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Scores from episode 499: [-0.0366667   1.06333336] (goalies), [-1.06333336  0.0366667 ] (strikers)
# Scores from episode 500: [1.00166669 1.00166669] (goalies), [-1.00166669 -1.00166669] (strikers)
# Red Wins: 	155 	Score: 	0.00000 	Avg: 	24.20 	Draws: 	212
